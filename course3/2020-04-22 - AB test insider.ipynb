# %% [markdown]
# ### Считаем данные

# %%
import os
import matplotlib
import scipy
import pandas as pd
import numpy as np
import re
from datetime import datetime
from google.cloud import bigquery
#работа с google sheets
#from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from pprint import pprint
from googleapiclient import discovery
#import pixiedust

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\zemskov.pavel\Downloads\Santehnika-Online-fda3a0f6de06.json"
# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

# %%
client = bigquery.Client()
dataset_id = 'Reports_Svod'
table_id = 'Daily_Campaign2_part_Static'

query = (    """ select * FROM `spry-compound-139714.sandbox.2020_04_22` """)
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location='US')  # API request - starts the query

result_query=query_job.result().to_dataframe().fillna(0)

# %%
result_query.head()
# Out:
#                              sessionid               clientid    medium  \
# 0  1004987941.1587464116_1587465417354  1004987941.1587464116  referral
# 1   100589599.1581152697_1587458940866   100589599.1581152697   organic
# 2  1024017451.1587302477_1587446225517  1024017451.1587302477       cpc
# 3  1074734903.1587127245_1587474049114  1074734903.1587127245       cpc
# 4  1080499892.1352705853_1587464210546  1080499892.1352705853  referral
#
#       source                                           campaign device_cat  \
# 0  yandex.ru                                          (not set)    desktop
# 1     yandex                                          (not set)     tablet
# 2     google  kms-umnaya_kms-none-0-moskva-obshchaia-1055391502     mobile
# 3     google  kms-umnaya_kms-none-0-moskva-obshchaia-1055391502     tablet
# 4  yandex.ru                                          (not set)    desktop
#
#          date order_id  transactionRevenue            region  \
# ...

# %%
only_
